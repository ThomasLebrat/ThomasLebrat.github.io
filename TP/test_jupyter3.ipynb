# %%
(scimax-jupyter-advise)

# %%
(scimax-jupyter-org-hydra/body)

# %% [markdown]
#     for i in range(3):
#         print(i)
#
# 0
# 1
# 2
#
#     import numpy as np
#     np.linspace
#
# <function numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)>
#
#     np.

# %% [markdown]
# ### plotly

# %% [markdown]
#     from pycse.plotly import *
#     import plotly.express as px
#
#     df = px.data.iris()
#     fig = px.scatter(df, x="sepal_width", y="sepal_length", color ="species",
#                      size ="petal_length", hover_data=['petal_width'])
#     fig.show()
#
# TypeErrorTraceback (most recent call last)
# <ipython-input-8-ddd507e31254> in <module>
#       5 fig = px.scatter(df, x="sepal\_width", y="sepal\_length", color `"species",
#       6                  size ="petal_length", hover_data`['petal\_width'])
# -&#x2014;> 7 fig.show()
#
# ~/.local/lib/python3.8/site-packages/pycse/plotly.py in myshow(self, \*args, \*\*kwargs)
#      28         f.write(html)
#      29
# &#x2014;> 30     display(FileLink(fhtml, result\_html\_suffix=""))
#      31
#      32     return Image(pio.to\_image(self, "png", engine="kaleido"))
#
# TypeError: 'module' object is not callable
#
#     from pycse.orgmode import *
#     import matplotlib.pyplot as plt
#
#     data = [['x', 'y'], None, [1, 2], [2, 4]]
#     org.table(data, name='table-data', caption='Data from a python table')
#
#     print()
#
#     plt.plot([4, 5, 6])
#     org.figure(plt.savefig('images/a-figure.png'), name='fig:1', caption='A figure in org-mode')
#
# :RESULTS:
#
# AttributeErrorTraceback (most recent call last)
# <ipython-input-9-1b87fd9b57c9> in <module>
#       3
#       4 data = [['x', 'y'], None, [1, 2], [2, 4]]
# -&#x2014;> 5 org.table(data, name='table-data', caption='Data from a python table')
#       6
#       7 print()
#
# AttributeError: module 'pycse.orgmode' has no attri [[\*\* plotly
#
#     from pycse.plotly import *
#     import plotly.express as px
#
#     df = px.data.iris()
#     fig = px.scatter(df, x="sepal_width", y="sepal_length", color ="species",
#                      size ="petal_length", hover_data=['petal_width'])
#     fig.show()
#
#     import pycse.orgmode as org
#     import matplotlib.pyplot as plt
#
#     data = [['x', 'y'], None, [1, 2], [2, 4]]
#     org.table(data, name='table-data', caption='Data from a python table')
#
#     print()
#
#     plt.plot([4, 5, 6])
#     org.figure(plt.savefig('images/a-figure.png'), name='fig:1', caption='A figure in org-mode')

# %% [markdown]
# #### test pyces

# %% [markdown]
#     from pycse.plotly import *
#
#     import plotly.express as px
#     df = px.data.iris()
#     fig = px.scatter(df, x="sepal_width", y="sepal_length", color = "species", size = "petal_length", hover_data=['petal_width'])
#
#     fig.show()
#
# TypeErrorTraceback (most recent call last)
# <ipython-input-1-0de3666b2768> in <module>
#       5 fig = px.scatter(df, x="sepal\_width", y="sepal\_length", color = "species", size = "petal\_length", hover\_data=['petal\_width'])
#       6
# -&#x2014;> 7 fig.show()
#
# ~/.local/lib/python3.8/site-packages/pycse/plotly.py in myshow(self, \*args, \*\*kwargs)
#      28         f.write(html)
#      29
# &#x2014;> 30     display(FileLink(fhtml, result\_html\_suffix=""))
#      31
#      32     return Image(pio.to\_image(self, "png", engine="kaleido"))
#
# TypeError: 'module' object is not callable
#
# ]] bute 'table'

# %% [markdown]
# #### test pyces

# %% [markdown]
#     from pycse.plotly import *
#
#     import plotly.express as px
#     df = px.data.iris()
#     fig = px.scatter(df, x="sepal_width", y="sepal_length", color = "species", size = "petal_length", hover_data=['petal_width'])
#
#     fig.show()
#
# TypeErrorTraceback (most recent call last)
# <ipython-input-1-0de3666b2768> in <module>
#       5 fig = px.scatter(df, x="sepal\_width", y="sepal\_length", color = "species", size = "petal\_length", hover\_data=['petal\_width'])
#       6
# -&#x2014;> 7 fig.show()
#
# ~/.local/lib/python3.8/site-packages/pycse/plotly.py in myshow(self, \*args, \*\*kwargs)
#      28         f.write(html)
#      29
# &#x2014;> 30     display(FileLink(fhtml, result\_html\_suffix=""))
#      31
#      32     return Image(pio.to\_image(self, "png", engine="kaleido"))
#
# TypeError: 'module' object is not callable
